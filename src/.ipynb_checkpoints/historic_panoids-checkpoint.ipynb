# %%
import sys
import os
import streetview_edited as streetview
import pandas as pd
import json
import requests
import multiprocessing as mproc
import time

# %%
def panoids_with_timeout(lst_result, lat, lon):
    lst_result.extend(streetview.panoids(lat, lon))

# %%
DATA_FOLDER = '../data'
apicallbase = 'https://maps.googleapis.com/maps/api/streetview/metadata?&pano='
mykey = 'AIzaSyDiyJQYyVPaQ_GAamLY_AXmLiJBDo0Lyk4'

# %%
columns = ['pt_lat','pt_lng', 'pano_id', 'r_lat', 'r_lng', 'year', 'month']
results = pd.DataFrame(columns=columns)

# %%
columns = ['id','pt_lat','pt_lng', 'pano_id', 'r_lat', 'r_lng', 'year', 'month']
results = pd.DataFrame(columns=columns)
 
pts = pd.read_csv(os.path.join(os.path.join(DATA_FOLDER, 'preston_PUA_random_points_2000.csv')))

# %%
#pts = pd.read_csv(os.path.join(DATA_FOLDER, 'points.csv'))

# %%
import signal

def signal_handler(signum, frame):
    raise Exception("Timed out!")

signal.signal(signal.SIGALRM, signal_handler)
signal.alarm(2)   # Ten seconds

for index, row in pts.iterrows():
    lst_result = []
    try:
        panoids_with_timeout(lst_result, row['Y'], row['X'])
    except Exception, msg:
        continue
    for record in lst_result:
            metadata = json.load(urllib.request.urlopen(apicallbase+record['panoid']+'&key='+mykey))
            year = (metadata['date'])[:4]
            month = (metadata['date'])[5:]
            results = results.append({  'id':row['id'],
                                        'pt_lat' : row['Y'],
                                        'pt_lng' : row['X'],
                                        'pano_id' : record['panoid'],
                                        'r_lat' : record['lat'],
                                        'r_lng': record['lon'],
                                        'year' : record['year'] if 'year' in record else year,
                                        'month' : record['month'] if 'month' in record else month}, ignore_index=True)
results.to_csv(os.path.join(DATA_FOLDER, 'results_preston.csv'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-4c20d6229ca7> in <module>()
#      14         continue
#      15     for record in lst_result:
# ---> 16             metadata = json.load(urllib.request.urlopen(apicallbase+record['panoid']+'&key='+mykey))
#      17             year = (metadata['date'])[:4]
#      18             month = (metadata['date'])[5:]
#
# NameError: name 'urllib' is not defined

# %%
columns = ['id','pt_lat','pt_lng', 'pano_id', 'r_lat', 'r_lng', 'year', 'month']
results = pd.DataFrame(columns=columns)
 
pts = pd.read_csv(os.path.join(os.path.join(DATA_FOLDER, 'crawley_random_points_2000.csv')))
 
for index, row in pts.iterrows():
    for record in streetview.panoids(lat=row['Y'], lon=row['X']):
        try:
            results = results.append({  'id':row['id'],
                                        'pt_lat' : row['Y'],
                                        'pt_lng' : row['X'],
                                        'pano_id' : record['panoid'],
                                        'r_lat' : record['lat'],
                                        'r_lng': record['lon'],
                                        'year' : record['year'] if 'year' in record else '',
                                        'month' : record['month'] if 'month' in record else ''}, ignore_index=True)
        except Exception as e:
            continue
results
 
results.to_csv(os.path.join('crawley.csv'))
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-8-3d531c3fd478> in <module>()
#       5
#       6 for index, row in pts.iterrows():
# ----> 7     for record in streetview.panoids(lat=row['Y'], lon=row['X']):
#       8         try:
#       9             results = results.append({  'id':row['id'],
#
# /Users/manu/Documents/pyWorkspace/streetview-historic/src/streetview_edited.py in panoids(lat, lon, closest, disp)
#      61     """
#      62
# ---> 63     resp = _panoids_data(lat, lon)
#      64
#      65     # Get all the panorama ids and coordinates
#
# /Users/manu/Documents/pyWorkspace/streetview-historic/src/streetview_edited.py in _panoids_data(lat, lon)
#      51     """
#      52     url = _panoids_url(lat, lon)
# ---> 53     return requests.get(url)
#      54
#      55
#
# /usr/local/lib/python2.7/site-packages/requests/api.pyc in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /usr/local/lib/python2.7/site-packages/requests/api.pyc in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /usr/local/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     516         }
#     517         send_kwargs.update(settings)
# --> 518         resp = self.send(prep, **send_kwargs)
#     519
#     520         return resp
#
# /usr/local/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     637
#     638         # Send the request
# --> 639         r = adapter.send(request, **kwargs)
#     640
#     641         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     486
#     487         except (ProtocolError, socket.error) as err:
# --> 488             raise ConnectionError(err, request=request)
#     489
#     490         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', error(50, 'Network is down'))

# %%
columns = ['id','pt_lat','pt_lng', 'pano_id', 'r_lat', 'r_lng', 'year', 'month']
results = pd.DataFrame(columns=columns)
 
pts = pd.read_csv(os.path.join(os.path.join(DATA_FOLDER, 'Hull_random_points_2000.csv')))
 
for index, row in pts.iterrows():
    try:
        for record in streetview.panoids(lat=row['Y'], lon=row['X']):
            results = results.append({  'id':row['id'],
                                        'pt_lat' : row['Y'],
                                        'pt_lng' : row['X'],
                                        'pano_id' : record['panoid'],
                                        'r_lat' : record['lat'],
                                        'r_lng': record['lon'],
                                        'year' : record['year'] if 'year' in record else '',
                                        'month' : record['month'] if 'month' in record else ''}, ignore_index=True)
        except Exception as e:
            continue
results
 
results.to_csv(os.path.join('hull.csv'))

# %%
columns = ['id','pt_lat','pt_lng', 'pano_id', 'r_lat', 'r_lng', 'year', 'month']
results = pd.DataFrame(columns=columns)
 
pts = pd.read_csv(os.path.join(os.path.join(DATA_FOLDER, 'Manchester_random_points_2000.csv')))
 
for index, row in pts.iterrows():
    for record in streetview.panoids(lat=row['Y'], lon=row['X']):
        results = results.append({  'id':row['id'],
                                    'pt_lat' : row['Y'],
                                    'pt_lng' : row['X'],
                                    'pano_id' : record['panoid'],
                                    'r_lat' : record['lat'],
                                    'r_lng': record['lon'],
                                    'year' : record['year'] if 'year' in record else '',
                                    'month' : record['month'] if 'month' in record else ''}, ignore_index=True)
results
 
results.to_csv(os.path.join('manchester.csv'))

# %%
for index, row in pts.iterrows():
    for record in streetview.panoids(lat=row['lat'], lon=row['lng']):
        metadata = json.load(urllib.request.urlopen(apicallbase+record['panoid']+'&key='+mykey))
        year = (metadata['date'])[:4]
        month = (metadata['date'])[5:]
        results = results.append({  'pt_lat' : row['lat'],
                                    'pt_lng' : row['lng'],
                                    'pano_id' : record['panoid'],
                                    'r_lat' : record['lat'],
                                    'r_lng': record['lon'],
                                    'year' : record['year'] if 'year' in record else year,
                                    'month' : record['month'] if 'month' in record else month}, ignore_index=True)

# %%
results
# Out:
#        pt_lat      pt_lng                 pano_id      r_lat       r_lng  \
# 0  -33.856939  151.214490  pV6jtRc157XZtWpVIR-rtg -33.856939  151.214490
# 1  -33.856939  151.214490  mH57MBnD6z1VusFNzvrEoA -33.857695  151.214286
# 2  -33.856939  151.214490  Gq1gccXGTM0UCdkxIvjvkg -33.857939  151.214221
# 3  -33.856939  151.214490  8eJDJnbtDVD6Tf8wO9c-hg -33.857977  151.214240
# 4  -33.856939  151.214490  uJULZnEQVGY8r4vTl-ANnQ -33.858071  151.214052
# 5  -33.856939  151.214490  KLitJuDdzwTZ0sddilV2nw -33.857772  151.214268
# 6  -33.856939  151.214490  pNbIKmkyJnr7B2TQWk3sxg -33.857832  151.214250
# 7  -33.856939  151.214490  jojVCc9UmxJXxMM4vgAFTQ -33.857458  151.214348
# 8  -33.856939  151.214490  JMbTwAvB2zOa_TfcLCKSwQ -33.857489  151.214345
# 9  -33.856939  151.214490  kcN9LIKykUf7Ivo4EdqihA -33.857651  151.214295
# 10 -33.856939  151.214490  QHQTTGU4c5FPNTRAef8NMQ -33.857282  151.214387
# 11 -33.856939  151.214490  Dnwib32GDUwR0ZEUpaRjwA -33.857215  151.214409
# 12 -33.856939  151.214490  fyU-UFzcm46oYIHpfaqdEA -33.857153  151.214428
# 13 -33.856939  151.214490  UnQPs_i5Ve4PKBsiiKCGIg -33.857093  151.214451
# 14 -33.856939  151.214490  OH7ReEUauWGKYqUwff4csA -33.857011  151.214474
# 15 -33.856939  151.214490  OnYNY2pKaDwzFGfyJeLqNg -33.856439  151.214621
# 16 -33.856939  151.214490  I95doIUXhL83xMfzNEqR1Q -33.856177  151.214660
# 17 -33.856939  151.214490  rIEeGHBXWkxsaZK7CHniIg -33.856241  151.214689
# 18 -33.856939  151.214490  3kk0PXBCYzWq9XFxkynAUg -33.856364  151.214640
# 19 -33.856939  151.214490  U-xGOUhYBvhoQLW3fRWiMQ -33.856500  151.214605
# 20 -33.856939  151.214490  0Ih6zwlaAi7BJBPMyCGzIw -33.856567  151.214590
# 21 -33.856939  151.214490  iEEnn7eeubWaaOGtgyZFkA -33.856645  151.214567
# 22 -33.856939  151.214490  D2hYV0KIE5z2DT3zKISPIw -33.856730  151.214546
# 23 -33.856939  151.214490  T3Olav_5BHcO4mp26-p5uA -33.856797  151.214532
# 24 -33.856939  151.214490  pV6jtRc157XZtWpVIR-rtg -33.856939  151.214490
# 25 -33.856939  151.214490  aX3nhhCruYOr-i1vSef13Q -33.856861  151.214511
# 26  41.878114  -87.629798  DgNezf4jU6IAAAQYLE57aQ  41.878114  -87.629798
#
#     year month
# 0   2015    12
# 1   2015    12
# 2   2015    12
# 3   2015    12
# 4   2015    12
# 5   2015    12
# 6   2015    12
# 7   2015    12
# 8   2015    12
# 9   2015    12
# 10  2015    12
# 11  2015    12
# 12  2015    12
# 13  2015    12
# 14  2015    12
# 15  2015    12
# 16  2015    12
# 17  2015    12
# 18  2015    12
# 19  2015    12
# 20  2015    12
# 21  2015    12
# 22  2015    12
# 23  2015    12
# 24  2015    12
# 25  2015    12
# 26  2010     8

# %%
results.to_csv(os.path.join(DATA_FOLDER, 'results.csv'))
